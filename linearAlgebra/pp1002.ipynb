# %%
import numpy as np

# %%
v1 = np.array([1, 2, 3])
v2 = np.array([2, 4, 5])

cos = np.dot(v1, v2) / (np.linalg.norm(v1) * np.linalg.norm(v2))

cos
# Out:
# 0.9960238411119946

# %%
print(np.dot(v1, v2))
print(v1.dot(v2))
# Out:
# 25
# 25

# %%
import matplotlib.pyplot as plt

nPerClust = 100

blur = 0.5

A = [1, 1]
B = [-3, 1]
C = [3, 3]

a = [A[0] + np.random.randn(nPerClust) * blur, A[1] + np.random.randn(nPerClust)]
b = [B[0] + np.random.randn(nPerClust) * blur, B[1] + np.random.randn(nPerClust)]
c = [C[0] + np.random.randn(nPerClust) * blur, C[1] + np.random.randn(nPerClust)]

data = np.transpose(np.concatenate((a, b, c), axis = 1))

tm0 = np.concatenate((a, b, c), axis = 1)
tm1 = np.concatenate((a, b, c), axis = 0)

print(data[1:2, 1:2], "\n", data)

"""

pA = lst[np.random.randint(low=0, high=len(lst))]
lst.remove(pA)
pB = lst[np.random.randint(low=0, high=len(lst))]
lst.remove(pB)
pC = lst[np.random.randint(low=0, high=len(lst))]
lst.remove(pC)

while (len(lst) <= 0) :
    test = lst[np.random.randint(low=0, high=len(lst))]
    min = 10000
    for k in lst :
        if (abs(k[0]*k[0] + k[1]*k[1]) < min) :
            pass
        
"""
clr = ['w', 'r', 'b']
for i in range(0, 3, 1) :
    plt.plot(data)

plt.plot(data[0:100, 0], data[0:100, 1], 'ko', markerfacecolor='w')
plt.plot(data[100:200, 0], data[100:200, 1], 'ko', markerfacecolor='r')
plt.plot(data[200:300, 0], data[200:300, 1], 'ko', markerfacecolor='b')

plt.title("RAW DATA")

plt.grid()
plt.show()
# Out:
# [[0.75574424]]
#  [[ 1.14804346  1.54313621]
#  [ 0.5396878   0.75574424]
#  [ 1.14638007  0.43916839]
#  [ 0.85041945  1.29820282]
#  [ 1.12470776  0.4748258 ]
#  [ 1.06358675  0.09295516]
#  [ 0.93514366 -0.10792837]
#  [ 2.01612997  1.80032346]
#  [ 1.27897873  0.4132402 ]
#  [ 0.74540971  1.61746188]
#  [ 0.25090763  1.0266686 ]
#  [ 1.08275492  2.22787549]
#  [ 0.0588742   0.44141303]
#  [ 0.81494068  1.23298989]
#  [ 1.31490009  0.85640878]
#  [ 0.2212355   0.39631034]
#  [ 1.54129097  1.37533564]
#  [ 1.21841383  1.53491636]
#  [ 0.91135006 -0.11854565]
#  [ 1.64821055  1.44167911]
#  [ 1.154399    1.20548427]
#  [ 1.62412668  1.79835686]
#  [ 1.56086606 -0.42475635]
#  [ 0.69637718  2.29236965]
#  [ 0.26078523  3.41938396]
#  [ 2.22919394 -0.39223504]
#  [ 1.23247649  1.54240653]
#  [ 0.64906518  1.51867288]
#  [ 0.97188284 -0.95588001]
#  [ 1.34138719  0.9131809 ]
#  [ 0.65801398  0.64510385]
#  [ 0.3920389  -0.31813276]
#  [ 0.75719917  0.70373946]
#  [ 0.85742732  0.20227313]
#  [ 0.815916    1.93516772]
#  [ 0.62795751  1.70951759]
#  [ 0.74783322 -0.8111567 ]
#  [ 0.56269788  0.98404961]
#  [ 0.45242715  1.56608714]
#  [ 1.32466394  2.33791993]
